# %%
import hashlib
while True:
    password = input("Enter password or type exit: ")
    if password == "exit":
        break
    # Strength check
    if len(password) < 8:
        print("Weak password")
    else:
        print("Stronger password")
    # Hashing
hashed = hashlib.sha256(password.encode()).hexdigest()
print(hashed)
# Out:
# Enter password or type exit:  Fu*23
# Weak password
# f46965f9dbe7aa13faa99faf27d9e5dd02bf10d25b17d91e0492d22838ed9375
# Enter password or type exit:  Uwiem0179
# Stronger password
# edd1a797733264eaf277a242b075178142caa11900150ca6f42a1ce3c7e38c93
